# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from pymongo import MongoClient
import time
from datetime import datetime, timedelta

# %%
# Set up MongoDB connection
client = MongoClient('localhost',27017)
db = client.project
Movies_col = db["Movies"]
Movie_Albums_col = db["Movie_Albums"]
spotify_col = db["Spotify"]

# %%
# Spotify API credentials
client_id = "4db0521b60254bef948d398eb66aaafd"
client_secret = "b502ecc5b90e46d1b46de5b100bd0662"

# Auth manager
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret))

# %%
def get_all_movie_titles_by_date(start_date_str, end_date_str):
    
    start_date = datetime.strptime(start_date_str, "%Y-%m-%d")
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d")

    query = {"release_date": {
            "$gte": start_date_str,
            "$lte": end_date_str}}

    projection = {"_id": 0, "title": 1, "release_date": 1}
    cursor = db["Movies"].find(query, projection)

    movie_titles = []
    for doc in cursor:
        title = doc.get("title")
        if title:
            movie_titles.append(title)

    return movie_titles

movie_lists = get_all_movie_titles_by_date("2025-01-01", "2025-01-02")

# %%
def search_and_store_spotify_album(term):
    results = sp.search(q=term + "Movie Sound Track", type='album', limit=1)
    albums = results['albums']['items']

    for album in albums:
        Movie_Albums_col.insert_one({
            "search_term": term,
            "raw_data": album })

def fetch_spotify_albums_for_all_movies():
    movie_titles = movie_lists

    for title in movie_titles:
        try:
            search_and_store_spotify_album(title)
            print(f"Fetched album(s) for: {title}")
        except Exception as e:
            print(f"Error fetching for '{title}': {e}")

fetch_spotify_albums_for_all_movies()
# Out:
# Fetched album(s) for: The Wizard of the Emerald City, Part 1
# Fetched album(s) for: The Love Scam
# Fetched album(s) for: Don't Die: The Man Who Wants to Live Forever
# Fetched album(s) for: Eephus
# Fetched album(s) for: How to Make a Killing
# Fetched album(s) for: Seeking Haven for Mr. Rambo
# Fetched album(s) for: Reality+
# Fetched album(s) for: Rambo
# Fetched album(s) for: Dove osano le cicogne
# Fetched album(s) for: Quiet Life
# Fetched album(s) for: Knock on my Tver
# Fetched album(s) for: A Message from Martha
# Fetched album(s) for: Delirium
# Fetched album(s) for: Pororo: Underwater Adventure
# Fetched album(s) for: Mukkam Post Bombilwaadi
# Fetched album(s) for: Khashaba
# Fetched album(s) for: End of History
# Fetched album(s) for: All My Friends
# Fetched album(s) for: New Year's Concert 2025
# Fetched album(s) for: Géminis
# Fetched album(s) for: Checkmate
# Fetched album(s) for: Parvin
# Fetched album(s) for: WWE Best of Raw 2024 Special
# Fetched album(s) for: El Dashash
# Fetched album(s) for: Meteors
# Fetched album(s) for: Slow, rises the moon
# Fetched album(s) for: Mission Entity
# Fetched album(s) for: Gavin & Stacey: A Fond Farewell
# Fetched album(s) for: All Things End
# Fetched album(s) for: Pyramiden
# Fetched album(s) for: Pinkerton
# Fetched album(s) for: Jesse James
# Fetched album(s) for: Abyss
# Fetched album(s) for: Tur Rehberi
# Fetched album(s) for: Ride the Snake
# Fetched album(s) for: The King, the Swordsman and the Sorceress
# Fetched album(s) for: The Almond
# Fetched album(s) for: Bleed For Justice
# Fetched album(s) for: The Con Artist
# Fetched album(s) for: COMBATTERE
# Fetched album(s) for: Berenice
# Fetched album(s) for: Piecemeal
# Fetched album(s) for: A Capodanno tutti da me
# Fetched album(s) for: See-Saw
# Fetched album(s) for: The Devil Inside Her
# Fetched album(s) for: Post Malone: On His Terms
# Fetched album(s) for: The Hare: Death Do Us Part
# Fetched album(s) for: Open Brain, dans le cerveau des athlètes
# Fetched album(s) for: Mika Ex Machina
# Fetched album(s) for: A Cure for Grannies
# Fetched album(s) for: Notes to Dad
# Fetched album(s) for: TV4:s Nyårskarameller 2024
# Fetched album(s) for: Blue Devils
# Fetched album(s) for: Chebi. New Year
# Fetched album(s) for: Doğulu
# Fetched album(s) for: EL TANGO TE ESPERA
# Fetched album(s) for: FEAR
# Fetched album(s) for: Tick-Man
# Fetched album(s) for: Street Fighter 8 (Finish Him)
# Fetched album(s) for: Game of Catch
# Fetched album(s) for: Harvest Moon
# Fetched album(s) for: White Gardenia: The King James Bible
# Fetched album(s) for: UEFA Champions League : une saison capitale
# Fetched album(s) for: Poca Pon
# Fetched album(s) for: Ensaio Sobre Acordar
# Fetched album(s) for: Entity
# Fetched album(s) for: Vladimir Cauchemar aux Francofolies 2024
# Fetched album(s) for: Moonshadow – The Myth of Fahimeh
# Fetched album(s) for: Funeral
# Fetched album(s) for: Judge Dredd: Death is Coming
# Fetched album(s) for: Thought Bobbles
# Fetched album(s) for: Real Fake Streets
# Fetched album(s) for: Animals: Drugs, Sex and Fun!
# Fetched album(s) for: Eternal Ghosts
# Fetched album(s) for: Zaag
# Fetched album(s) for: Anarchy Before Fall
# Fetched album(s) for: Doug Stanhope: Discount Meat
# Fetched album(s) for: New Year's Eve Massacre 2
# Fetched album(s) for: Kevin James Doyle: Diary of a Bald Kid
# Fetched album(s) for: Fue en un café
# Fetched album(s) for: Flowers
# Fetched album(s) for: Rhino King
# Fetched album(s) for: Carsick
# Fetched album(s) for: Una Playa
# Fetched album(s) for: Order
# Fetched album(s) for: Tiszavirágok
# Fetched album(s) for: Six Weeks
# Fetched album(s) for: Good Luck!
# Fetched album(s) for: The Wind
# Fetched album(s) for: New Year, New Me
# Fetched album(s) for: A Home for Christmas
# Fetched album(s) for: Unholy
# Fetched album(s) for: Blue
# Fetched album(s) for: Child's Fare
# Fetched album(s) for: A Man Paints A Woman
# Fetched album(s) for: Das Ende der Vernunft
# Fetched album(s) for: Guy on the Outside
# Fetched album(s) for: Revoir la mère
# Fetched album(s) for: Suspicions About the Hidden Realities of Air
# Fetched album(s) for: Melissa Villaseñor: Welp...What Now?
# Fetched album(s) for: Entre Aulas
# Fetched album(s) for: City Rush 4
# Fetched album(s) for: Conceiving
# Fetched album(s) for: Waste Away
# Fetched album(s) for: Revolution 3.0
# Fetched album(s) for: White Scratch
# Fetched album(s) for: Creative Reasoning
# Fetched album(s) for: Ondin
# Fetched album(s) for: Amen Break
# Fetched album(s) for: Heiress Crash Lands on Her Husband
# Fetched album(s) for: Caronte
# Fetched album(s) for: Delicacy
# Fetched album(s) for: Animal Math
# Fetched album(s) for: ម្រឹត្យូវ ប្រម៉ាត់ត្រយ៉ូវ
# Fetched album(s) for: Maracá
# Fetched album(s) for: Shalabham
# Fetched album(s) for: Suspiro
# Fetched album(s) for: Janus
# Fetched album(s) for: Justice: The Movie
# Fetched album(s) for: Guys' Night in The Thing
# Fetched album(s) for: Paint Me Blue
# Fetched album(s) for: Hodge Podge
# Fetched album(s) for: Skull And Stare Alone
# Fetched album(s) for: 22
# Fetched album(s) for: Dollhouse
# Fetched album(s) for: Faceless Facade
# Fetched album(s) for: Bulldozer Live In Saint Louis
# Fetched album(s) for: Short Circuit
# Fetched album(s) for: Out From the Egg
# Fetched album(s) for: All This Time
# Fetched album(s) for: Harmony Inc.
# Fetched album(s) for: From The Tree Line
# Fetched album(s) for: A Theory I Dreamt Up in London
# Fetched album(s) for: Burners
# Fetched album(s) for: The Smash Bros Movie
# Fetched album(s) for: White Gardenia- John Calvin and Other Excerpts From The King James Bible
# Fetched album(s) for: The Girl in Kelp
# Fetched album(s) for: Jay Light: My Wife Hates These Jokes
# Fetched album(s) for: Revert
# Fetched album(s) for: Distance to the Moon
# Fetched album(s) for: Therapy
# Fetched album(s) for: Forty
# Fetched album(s) for: Karališkas blefas. Naujieji metai
# Fetched album(s) for: Les Bravos d'or
# Fetched album(s) for: 8 BUCKS TYCOON
# Fetched album(s) for: Red Dust
# Fetched album(s) for: Eighteen
# Fetched album(s) for: WHERE DO YOU CALL HOME?
# Fetched album(s) for: El arte de la sociedad
# Fetched album(s) for: L'ornitologa
# Fetched album(s) for: centipedefuture.mp4
# Fetched album(s) for: River Story
# Fetched album(s) for: Storm Clouds
# Fetched album(s) for: Unanounced Cort Studios Project
# Fetched album(s) for: Girl in the Night
# Fetched album(s) for: CHIRIBIQUETE: Encounter of Roots
# Fetched album(s) for: Which Way Should My Chimney Face?
# Fetched album(s) for: Jogado na Nuvem
# Fetched album(s) for: Everything Goes Out
# Fetched album(s) for: Accident
# Fetched album(s) for: 120 Days of Sodom Literally
# Fetched album(s) for: Vane
# Fetched album(s) for: Coral Sea
# Fetched album(s) for: Panivizhum Iravu: The Onset
# Fetched album(s) for: Éveil
# Fetched album(s) for: Zeinab al-moto
# Fetched album(s) for: Breloques
# Fetched album(s) for: Monument to a Period of Time in Which I Lived
# Fetched album(s) for: Benatzky!
# Fetched album(s) for: Arthur Ave.
# Fetched album(s) for: When in doubt, go left
# Fetched album(s) for: Obelisk: Bunker to Beacon and Back (and admiration for Paul Rudolph's Mental Health Center)
# Fetched album(s) for: Y2Kevin
# Fetched album(s) for: The Red List
# Fetched album(s) for: Laços & Sangue
# Fetched album(s) for: What Happened at Auschwitz
# Fetched album(s) for: Awaiting a murder
# Fetched album(s) for: 2024: Celebs We Cancelled
# Fetched album(s) for: Love Spell Cake
# Fetched album(s) for: Ben Kochan - No Coffee No Workee
# Fetched album(s) for: 100 ans, l'héritage d'une vie.
# Fetched album(s) for: First Draft
# Fetched album(s) for: Bouddha
# Fetched album(s) for: Dracula Citgo
# Fetched album(s) for: 2024.mov
# Fetched album(s) for: Salmo - leva på hoppet
# Fetched album(s) for: Greek Pistol
# Fetched album(s) for: Where am I heading, Where am I from
# Fetched album(s) for: Rocketship
# Fetched album(s) for: J'entends que les sirènes
# Fetched album(s) for: The Spirit Who Swims
# Fetched album(s) for: Sutura
# Fetched album(s) for: Sexability - A Story About Duchenne Muscular Dystrophy and Love
# Fetched album(s) for: Ou os Dias de Rotina
# Fetched album(s) for: Bagye Juon - János bátya
# Fetched album(s) for: Denmo - Himalayan Brown Bear
# Fetched album(s) for: Titanic Modhiya Iceberg Ivan
# Fetched album(s) for: The Path of Puma-36
# Fetched album(s) for: Rotating Signals
# Fetched album(s) for: Burrowing Owls: A Love Story
# Fetched album(s) for: Luke-Alike
# Fetched album(s) for: Kim: Masum?
# Fetched album(s) for: Terlahir Kembali
# Fetched album(s) for: Passage
# Fetched album(s) for: Rickard & Dio
# Fetched album(s) for: Untitled Tennis Documentary Film by Youssef Askar
# Fetched album(s) for: Faux Amis
# Fetched album(s) for: The City And...
# Fetched album(s) for: En traversée
# Fetched album(s) for: Not Alone
# Fetched album(s) for: Good News, Good News
# Fetched album(s) for: Nos esprits sont comme occupés
# Fetched album(s) for: A Letter So Long
# Fetched album(s) for: The Path to Perfection 2
# Fetched album(s) for: Take Away
# Fetched album(s) for: At the shadow of the world
# Fetched album(s) for: Aires
# Fetched album(s) for: Invisible Sister
# Fetched album(s) for: Wander Alone
# Fetched album(s) for: Shades of Blue
# Fetched album(s) for: Prince of Nothing
# Fetched album(s) for: Jiffy Lube
# Fetched album(s) for: Conversation One Night
# Fetched album(s) for: The Wizard of the Emerald City, Part 1
# Fetched album(s) for: Squid Game: Making Season 2
# Fetched album(s) for: The Love Scam
# Fetched album(s) for: Don't Die: The Man Who Wants to Live Forever
# Fetched album(s) for: Eephus
# Fetched album(s) for: How to Make a Killing
# Fetched album(s) for: Seeking Haven for Mr. Rambo
# Fetched album(s) for: Reality+
# Fetched album(s) for: Rambo
# Fetched album(s) for: Identity
# Fetched album(s) for: Kayara
# Fetched album(s) for: Dove osano le cicogne
# Fetched album(s) for: Quiet Life
# Fetched album(s) for: And the Breadwinner Is...
# Fetched album(s) for: Umjolo: My Beginning, My End!
# Fetched album(s) for: Mundije
# Fetched album(s) for: Knock on my Tver
# Fetched album(s) for: A Message from Martha
# Fetched album(s) for: Hobal
# Fetched album(s) for: Delirium
# Fetched album(s) for: Pororo: Underwater Adventure
# Fetched album(s) for: Mukkam Post Bombilwaadi
# Fetched album(s) for: Khashaba
# Fetched album(s) for: End of History
# Fetched album(s) for: All My Friends
# Fetched album(s) for: New Year's Concert 2025
# Fetched album(s) for: Gene Kelly - An American in Hollywood
# Fetched album(s) for: Zanna: Whisper of Volcano Isle
# Fetched album(s) for: Utusan Iblis: Dia Yang Berada di Antara Kita
# Fetched album(s) for: Géminis
# Fetched album(s) for: Thou Shalt Kill
# Fetched album(s) for: Checkmate
# Fetched album(s) for: Parvin
# Fetched album(s) for: WWE Best of Raw 2024 Special
# Fetched album(s) for: El Dashash
# Fetched album(s) for: Meteors
# Fetched album(s) for: Slow, rises the moon
# Fetched album(s) for: Mission Entity
# Fetched album(s) for: Gavin & Stacey: A Fond Farewell
# Fetched album(s) for: All Things End
# Fetched album(s) for: Pyramiden
# Fetched album(s) for: Slow Train
# Fetched album(s) for: Pinkerton
# Fetched album(s) for: Razakar
# Fetched album(s) for: Evil of the Rat
# Fetched album(s) for: Jesse James
# Fetched album(s) for: Abyss
# Fetched album(s) for: Tur Rehberi
# Fetched album(s) for: Badminton
# Fetched album(s) for: Ride the Snake
# Fetched album(s) for: The King, the Swordsman and the Sorceress
# Fetched album(s) for: The Almond
# Fetched album(s) for: New York Post Presents: Luigi Mangione Monster or Martyr?
# Fetched album(s) for: Bleed For Justice
# Fetched album(s) for: Papa
# Fetched album(s) for: The Con Artist
# Fetched album(s) for: Les Toxiques
# Fetched album(s) for: COMBATTERE
# Fetched album(s) for: Berenice
# Fetched album(s) for: Neshoma
# Fetched album(s) for: Piecemeal
# Fetched album(s) for: A Capodanno tutti da me
# Fetched album(s) for: See-Saw
# Fetched album(s) for: Antara
# Fetched album(s) for: The Devil Inside Her
# Fetched album(s) for: Long Story Short
# Fetched album(s) for: Post Malone: On His Terms
# Fetched album(s) for: The Hare: Death Do Us Part
# Fetched album(s) for: Don Jediondo Recharged
# Fetched album(s) for: Katha Kamamishu
# Fetched album(s) for: Open Brain, dans le cerveau des athlètes
# Fetched album(s) for: Mika Ex Machina
# Fetched album(s) for: A Cure for Grannies
# Fetched album(s) for: Notes to Dad
# Fetched album(s) for: TV4:s Nyårskarameller 2024
# Fetched album(s) for: Blue Devils
# Fetched album(s) for: Chebi. New Year
# Fetched album(s) for: Doğulu
# Fetched album(s) for: EL TANGO TE ESPERA
# Fetched album(s) for: FEAR
# Fetched album(s) for: Tick-Man
# Fetched album(s) for: Street Fighter 8 (Finish Him)
# Fetched album(s) for: Game of Catch
# Fetched album(s) for: Harvest Moon
# Fetched album(s) for: White Gardenia: The King James Bible
# Fetched album(s) for: UEFA Champions League : une saison capitale
# Fetched album(s) for: Poca Pon
# Fetched album(s) for: Ensaio Sobre Acordar
# Fetched album(s) for: Entity
# Fetched album(s) for: Vladimir Cauchemar aux Francofolies 2024
# Fetched album(s) for: Moonshadow – The Myth of Fahimeh
# Fetched album(s) for: Enredo de Reyes
# Fetched album(s) for: Funeral
# Fetched album(s) for: Judge Dredd: Death is Coming
# Fetched album(s) for: Cocaine Roach
# Fetched album(s) for: Follow the Stickers
# Fetched album(s) for: Thought Bobbles
# Fetched album(s) for: Real Fake Streets
# Fetched album(s) for: Animals: Drugs, Sex and Fun!
# Fetched album(s) for: Eternal Ghosts
# Fetched album(s) for: Zaag
# Fetched album(s) for: Anarchy Before Fall
# Fetched album(s) for: Doug Stanhope: Discount Meat
# Fetched album(s) for: New Year's Eve Massacre 2
# Fetched album(s) for: Kevin James Doyle: Diary of a Bald Kid
# Fetched album(s) for: Fue en un café
# Fetched album(s) for: Shangai
# Fetched album(s) for: Flowers
# Fetched album(s) for: Dottie Vs The Future
# Fetched album(s) for: ¿Y no invitas?
# Fetched album(s) for: Guardians of the Harvest
# Fetched album(s) for: Mom's House
# Fetched album(s) for: Rhino King
# Fetched album(s) for: Carsick
# Fetched album(s) for: Mi amor
# Fetched album(s) for: Both of Us in the Center of the World
# Fetched album(s) for: Una Playa
# Fetched album(s) for: Order
# Fetched album(s) for: Tiszavirágok
# Fetched album(s) for: Six Weeks
# Fetched album(s) for: Good Luck!
# Fetched album(s) for: The Wind
# Fetched album(s) for: New Year, New Me
# Fetched album(s) for: A Home for Christmas
# Fetched album(s) for: Unholy
# Fetched album(s) for: Blue
# Fetched album(s) for: Za oponou velehor
# Fetched album(s) for: Child's Fare
# Fetched album(s) for: Lali Symon
# Fetched album(s) for: A Man Paints A Woman
# Fetched album(s) for: Das Ende der Vernunft
# Fetched album(s) for: Guga Baúl & Jonas Van Thielen - Badje Vol met Stroop XXL
# Fetched album(s) for: Guy on the Outside
# Fetched album(s) for: Revoir la mère
# Fetched album(s) for: Suspicions About the Hidden Realities of Air
# Fetched album(s) for: Melissa Villaseñor: Welp...What Now?
# Fetched album(s) for: Entre Aulas
# Fetched album(s) for: 72 Hours
# Fetched album(s) for: City Rush 4
# Fetched album(s) for: Conceiving
# Fetched album(s) for: Waste Away
# Fetched album(s) for: Revolution 3.0
# Fetched album(s) for: White Scratch
# Fetched album(s) for: House at the End of the World
# Fetched album(s) for: Creative Reasoning
# Fetched album(s) for: Ondin
# Fetched album(s) for: Amen Break
# Fetched album(s) for: Heiress Crash Lands on Her Husband
# Fetched album(s) for: Caronte
# Fetched album(s) for: Delicacy
# Fetched album(s) for: Animal Math
# Fetched album(s) for: ម្រឹត្យូវ ប្រម៉ាត់ត្រយ៉ូវ
# Fetched album(s) for: Maracá
# Fetched album(s) for: Shalabham
# Fetched album(s) for: Suspiro
# Fetched album(s) for: Janus
# Fetched album(s) for: Justice: The Movie
# Fetched album(s) for: Guys' Night in The Thing
# Fetched album(s) for: Breaking Into Beautiful
# Fetched album(s) for: Not Human, But...
# Fetched album(s) for: Paint Me Blue
# Fetched album(s) for: Hodge Podge
# Fetched album(s) for: Skull And Stare Alone
# Fetched album(s) for: 22
# Fetched album(s) for: Dollhouse
# Fetched album(s) for: Faceless Facade
# Fetched album(s) for: Bulldozer Live In Saint Louis
# Fetched album(s) for: Short Circuit
# Fetched album(s) for: Out From the Egg
# Fetched album(s) for: All This Time
# Fetched album(s) for: Harmony Inc.
# Fetched album(s) for: Steve Buscemi
# Fetched album(s) for: Ajian Maut
# Fetched album(s) for: From The Tree Line
# Fetched album(s) for: A Theory I Dreamt Up in London
# Fetched album(s) for: Burners
# Fetched album(s) for: The Smash Bros Movie
# Fetched album(s) for: White Gardenia- John Calvin and Other Excerpts From The King James Bible
# Fetched album(s) for: The Girl in Kelp
# Fetched album(s) for: Jay Light: My Wife Hates These Jokes
# Fetched album(s) for: Revert
# Fetched album(s) for: Distance to the Moon
# Fetched album(s) for: Therapy
# Fetched album(s) for: Forty
# Fetched album(s) for: Karališkas blefas. Naujieji metai
# Fetched album(s) for: AVADHI THE TALE OF LOVE
# Fetched album(s) for: Les Bravos d'or
# Fetched album(s) for: 8 BUCKS TYCOON
# Fetched album(s) for: Riddleshafts.
# Fetched album(s) for: Red Dust
# Fetched album(s) for: Eighteen
# Fetched album(s) for: WHERE DO YOU CALL HOME?
# Fetched album(s) for: El arte de la sociedad
# Fetched album(s) for: L'ornitologa
# Fetched album(s) for: centipedefuture.mp4
# Fetched album(s) for: River Story
# Fetched album(s) for: Storm Clouds
# Fetched album(s) for: Unanounced Cort Studios Project
# Fetched album(s) for: Girl in the Night
# Fetched album(s) for: CHIRIBIQUETE: Encounter of Roots
# Fetched album(s) for: Which Way Should My Chimney Face?
# Fetched album(s) for: Jogado na Nuvem
# Fetched album(s) for: Everything Goes Out
# Fetched album(s) for: Accident
# Fetched album(s) for: 120 Days of Sodom Literally
# Fetched album(s) for: Vane
# Fetched album(s) for: Coral Sea
# Fetched album(s) for: Panivizhum Iravu: The Onset
# Fetched album(s) for: Éveil
# Fetched album(s) for: Zeinab al-moto
# Fetched album(s) for: Breloques
# Fetched album(s) for: Monument to a Period of Time in Which I Lived
# Fetched album(s) for: Benatzky!
# Fetched album(s) for: Arthur Ave.
# Fetched album(s) for: When in doubt, go left
# Fetched album(s) for: Augenblicke 2025
# Fetched album(s) for: The Poem
# Fetched album(s) for: Les bouillons parisiens, une histoire de goût
# Fetched album(s) for: Obelisk: Bunker to Beacon and Back (and admiration for Paul Rudolph's Mental Health Center)
# Fetched album(s) for: Y2Kevin
# Fetched album(s) for: The Red List
# Fetched album(s) for: Laços & Sangue
# Fetched album(s) for: What Happened at Auschwitz
# Fetched album(s) for: Stop - Salas De Ensaio Para Um Materialismo Histórico
# Fetched album(s) for: Da sua, Maria
# Fetched album(s) for: Awaiting a murder
# Fetched album(s) for: 2024: Celebs We Cancelled
# Fetched album(s) for: Love Spell Cake
# Fetched album(s) for: Ben Kochan - No Coffee No Workee
# Fetched album(s) for: Vampiress
# Fetched album(s) for: 100 ans, l'héritage d'une vie.
# Fetched album(s) for: First Draft
# Fetched album(s) for: Bouddha
# Fetched album(s) for: Dracula Citgo
# Fetched album(s) for: 2024.mov
# Fetched album(s) for: Salmo - leva på hoppet
# Fetched album(s) for: Greek Pistol
# Fetched album(s) for: Where am I heading, Where am I from
# Fetched album(s) for: Rocketship
# Fetched album(s) for: J'entends que les sirènes
# Fetched album(s) for: The Spirit Who Swims
# Fetched album(s) for: Sutura
# Fetched album(s) for: Get away from the window
# Fetched album(s) for: Sexability - A Story About Duchenne Muscular Dystrophy and Love
# Fetched album(s) for: Ou os Dias de Rotina
# Fetched album(s) for: Bagye Juon - János bátya
# Fetched album(s) for: On the Aftermath of Domestic Hyper-Interiority
# Fetched album(s) for: Denmo - Himalayan Brown Bear
# Fetched album(s) for: Titanic Modhiya Iceberg Ivan
# Fetched album(s) for: The Path of Puma-36
# Fetched album(s) for: Rotating Signals
# Fetched album(s) for: Burrowing Owls: A Love Story
# Fetched album(s) for: Luke-Alike
# Fetched album(s) for: Crocodrame
# Fetched album(s) for: Kim: Masum?
# Fetched album(s) for: Terlahir Kembali
# Fetched album(s) for: Passage
# Fetched album(s) for: Rickard & Dio
# Fetched album(s) for: Our Time
# Fetched album(s) for: Untitled Tennis Documentary Film by Youssef Askar
# Fetched album(s) for: Faux Amis
# Fetched album(s) for: The City And...
# Fetched album(s) for: En traversée
# Fetched album(s) for: Not Alone
# Fetched album(s) for: Good News, Good News
# Fetched album(s) for: Nos esprits sont comme occupés
# Fetched album(s) for: A Letter So Long
# Fetched album(s) for: The Path to Perfection 2
# Fetched album(s) for: No Politics At the Dining Table
# Fetched album(s) for: Take Away
# Fetched album(s) for: Stalker
# Fetched album(s) for: At the shadow of the world
# Fetched album(s) for: Aires
# Fetched album(s) for: Invisible Sister
# Fetched album(s) for: Wander Alone
# Fetched album(s) for: Shades of Blue
# Fetched album(s) for: Prince of Nothing
# Fetched album(s) for: Therapy (A Short Film)
# Fetched album(s) for: Υδατα
# Fetched album(s) for: Un día con yaya
# Fetched album(s) for: Jiffy Lube
# Fetched album(s) for: Conversation One Night

# %%
def get_album_ids_from_raw_data():
    album_ids = []
    cursor = db["Movie_Albums"].find({}, {"raw_data.id": 1})
    for doc in cursor:
        ids = doc["raw_data"]["id"]
        album_ids.append(ids)
    return album_ids

# %%
album_ids = get_album_ids_from_raw_data()
len(album_ids)
# Out:
# 53933

# %%
from collections import OrderedDict
from pprint import pprint

def fetch(album_ids):
    for index, album_id in enumerate(album_ids[10000:13000], start=10001):
        try:
            # Lookup from Movie_Albums
            movie_doc = db["Movie_Albums"].find_one({
                "$expr": { "$eq": ["$raw_data.id", album_id] }
            })

            if not movie_doc:
                print(f" Skipping. Album ID {album_id} not found in Movie_Albums.")
                continue

            movie_title = movie_doc.get("search_term", "UNKNOWN TITLE")
            raw_info = movie_doc.get("raw_data", {})

            album_info = {
                "album_id": raw_info.get("id"),
                "album_name": raw_info.get("name"),
                "release_date": raw_info.get("release_date"),
                "total_tracks": raw_info.get("total_tracks"),
                "spotify_url": raw_info.get("external_urls", {}).get("spotify"),
                "artists": [artist.get("name") for artist in raw_info.get("artists", [])]
            }

            # Fetch from Spotify API
            album_raw = sp.album(album_id)
            album_details = {
                "id": album_raw.get("id"),
                "name": album_raw.get("name"),
                "release_date": album_raw.get("release_date"),
                "total_tracks": album_raw.get("total_tracks"),
                "type": album_raw.get("album_type"),
                "uri": album_raw.get("uri"),
                "artists": album_raw.get("artists"),
                "tracks": album_raw.get("tracks"),
                "popularity": album_raw.get("popularity"),
                "label": album_raw.get("label"),
                "copyrights": album_raw.get("copyrights")
            }

            # Combine in desired order
            final_doc = OrderedDict()
            final_doc["movie_title"] = movie_title
            final_doc["album_info"] = album_info
            final_doc["album_details"] = album_details

            #  Store in Spotify collection
            db["spotify"].update_one(
                {"album_info.album_id": album_id},
                {"$set": final_doc},
                upsert=True
            )

            print(f" Stored to Spotify: {movie_title} ({album_id})")

        except Exception as e:
            print(f" Error processing album ID {album_id}: {e}")

fetch(album_ids)
# Out:
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 85334
#  Stored to Spotify: Inception (2qvA7HmSg1iM6XMiFF76dp)
